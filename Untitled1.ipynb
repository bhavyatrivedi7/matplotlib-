# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("d:\\train.csv")
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df1=df.isnull().sum()/df.shape[0]*100
df1
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
df2=df1[df1>17].keys()
df2
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
plt.figure(figsize=(25,25))
sns.heatmap(df.isnull())

# %%
final=df.drop(columns=df2)
final.shape
# Out:
# (1460, 75)

# %%
sns.heatmap(final.isnull())

# %%
df3=final.dropna()
df3.shape
# Out:
# (1338, 75)

# %%
sns.heatmap(df3.isnull())

# %%
df3.isnull().sum().sum()
# Out:
# 0

# %%
pd.concat([df["MSZoning"].value_counts()/df.shape[0]*100,
df3["MSZoning"].value_counts()/df3.shape[0]*100],axis=1,keys=["MSZoning","MSZoning new"])
# Out:
#           MSZoning  MSZoning new
# RL       78.835616     79.671151
# RM       14.931507     14.275037
# FV        4.452055      4.633782
# RH        1.095890      0.822123
# C (all)   0.684932      0.597907
